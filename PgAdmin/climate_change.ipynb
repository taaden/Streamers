# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
file_path = "../Resources/cleanUS_temp.csv"
cleanUS_temp_df = pd.read_csv(file_path)
cleanUS_temp_df.head()
# Out:
#          dt  Avg_temp  Avg_temp_Uncer    State        Country  id
# 0  1/1/1900     6.286           0.537  Alabama  United States NaN
# 1  2/1/1900     6.523           0.520  Alabama  United States NaN
# 2  3/1/1900    11.213           0.372  Alabama  United States NaN
# 3  4/1/1900    17.103           0.313  Alabama  United States NaN
# 4  5/1/1900    21.311           0.350  Alabama  United States NaN

# %%
file_path = "../Resources/cleanWorld_temp.csv"
cleanWorld_temp_df = pd.read_csv(file_path)
cleanWorld_temp_df.head()
# Out:
#          Date  LandAvg_temp  LandAvg_temp_Uncer  LandMax_temp  \
# 0  1900-01-01          1.46                0.28          7.19
# 1  1900-02-01          3.10                0.42          9.18
# 2  1900-03-01          5.49                0.26         11.38
# 3  1900-04-01          8.22                0.29         13.97
# 4  1900-05-01         11.38                0.36         17.42
#
#    LandMax_tempUncer  LandMin_temp  LandMin_tempUncer  LandOceanAvg_temp  \
# 0               0.47         -4.10               0.40              13.14
# 1               0.60         -2.81               0.63              13.78
# 2               0.33         -0.68               0.61              14.40
# 3               0.34          2.13               0.39              15.17
# 4               0.33          5.18               0.38              15.96
#
#    LandOceanAvg_tempUncer
# 0                    0.14
# 1                    0.17
# 2                    0.14
# 3                    0.15
# ...

# %%
file_path = "../Resources/Climate_change.csv"
Climate_change_df = pd.read_csv(file_path)
Climate_change_df.head()
# Out:
# C:\Users\feven\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Date  LandAvg_temp  LandAvg_temp_Uncer  LandMax_temp  \
# 0  1/1/1900          1.46                0.28          7.19
# 1  2/1/1900          3.10                0.42          9.18
# 2  3/1/1900          5.49                0.26         11.38
# 3  4/1/1900          8.22                0.29         13.97
# 4  5/1/1900         11.38                0.36         17.42
#
#    LandMax_tempUncer  LandMin_temp  LandMin_tempUncer  LandOceanAvg_temp  \
# 0               0.47         -4.10               0.40              13.14
# 1               0.60         -2.81               0.63              13.78
# 2               0.33         -0.68               0.61              14.40
# ...

# %%
from sqlalchemy import create_engine

# %%
from config import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/climate_change_db"

# %%
engine = create_engine(db_string)

# %%
cleanUS_temp_df.to_sql(name='cleanUS_temp', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_70488\790787496.py in <module>
# ----> 1 cleanUS_temp_df.to_sql(name='cleanUS_temp', con=engine)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ...

# %%
cleanWorld_temp_df.to_sql(name='cleanWorld_temp', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_70488\552935471.py in <module>
# ----> 1 cleanWorld_temp_df.to_sql(name='cleanWorld_temp', con=engine)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ...

# %%
Climate_change_df.to_sql(name='Climate_change', con=engine)
